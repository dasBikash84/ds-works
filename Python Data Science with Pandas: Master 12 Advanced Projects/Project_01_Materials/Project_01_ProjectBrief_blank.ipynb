# %% [markdown]
# # Project 1: Explanatory Data Analysis & Data Presentation (Movies Dataset)

# %% [markdown]
# # Project Brief for Self-Coders

# %% [markdown]
# Here you´ll have the opportunity to code major parts of Project 1 on your own. If you need any help or inspiration, have a look at the Videos or the Jupyter Notebook with the full code. <br> <br>
# Keep in mind that it´s all about __getting the right results/conclusions__. It´s not about finding the identical code. Things can be coded in many different ways. Even if you come to the same conclusions, it´s very unlikely that we have the very same code.

# %% [markdown]
# ## Data Import and first Inspection

# %% [markdown]
# 1. __Import__ the movies dataset from the CSV file "movies_complete.csv". __Inspect__ the data.

# %% [markdown]
# __Some additional information on Features/Columns__:

# %% [markdown]
# * **id:** The ID of the movie (clear/unique identifier).
# * **title:** The Official Title of the movie.
# * **tagline:** The tagline of the movie.
# * **release_date:** Theatrical Release Date of the movie.
# * **genres:** Genres associated with the movie.
# * **belongs_to_collection:** Gives information on the movie series/franchise the particular film belongs to.
# * **original_language:** The language in which the movie was originally shot in.
# * **budget_musd:** The budget of the movie in million dollars.
# * **revenue_musd:** The total revenue of the movie in million dollars.
# * **production_companies:** Production companies involved with the making of the movie.
# * **production_countries:** Countries where the movie was shot/produced in.
# * **vote_count:** The number of votes by users, as counted by TMDB.
# * **vote_average:** The average rating of the movie.
# * **popularity:** The Popularity Score assigned by TMDB.
# * **runtime:** The runtime of the movie in minutes.
# * **overview:** A brief blurb of the movie.
# * **spoken_languages:** Spoken languages in the film.
# * **poster_path:** The URL of the poster image.
# * **cast:** (Main) Actors appearing in the movie.
# * **cast_size:** number of Actors appearing in the movie.
# * **director:** Director of the movie.
# * **crew_size:** Size of the film crew (incl. director, excl. actors).

# %%
import numpy as np
import pandas as pd

# %%
movie_df = pd.read_csv('movies_complete.csv')

# %%
movie_df.T
# Out:
#                                                                    0      \
# id                                                                   862
# title                                                          Toy Story
# tagline                                                              NaN
# release_date                                                  1995-10-30
# genres                                           Animation|Comedy|Family
# belongs_to_collection                               Toy Story Collection
# original_language                                                     en
# budget_musd                                                         30.0
# revenue_musd                                                  373.554033
# production_companies                             Pixar Animation Studios
# production_countries                            United States of America
# vote_count                                                        5415.0
# vote_average                                                         7.7
# popularity                                                     21.946943
# runtime                                                             81.0
# overview               Led by Woody, Andy's toys live happily in his ...
# spoken_languages                                                 English
# poster_path            <img src='http://image.tmdb.org/t/p/w185//uXDf...
# cast                   Tom Hanks|Tim Allen|Don Rickles|Jim Varney|Wal...
# cast_size                                                             13
# crew_size                                                            106
# director                                                   John Lasseter
#
#                                                                    1      \
# id                                                                  8844
# title                                                            Jumanji
# tagline                        Roll the dice and unleash the excitement!
# release_date                                                  1995-12-15
# genres                                          Adventure|Fantasy|Family
# belongs_to_collection                                                NaN
# original_language                                                     en
# budget_musd                                                         65.0
# revenue_musd                                                  262.797249
# production_companies   TriStar Pictures|Teitler Film|Interscope Commu...
# production_countries                            United States of America
# vote_count                                                        2413.0
# vote_average                                                         6.9
# popularity                                                     17.015539
# runtime                                                            104.0
# overview               When siblings Judy and Peter discover an encha...
# spoken_languages                                        English|Français
# poster_path            <img src='http://image.tmdb.org/t/p/w185//vgpX...
# cast                   Robin Williams|Jonathan Hyde|Kirsten Dunst|Bra...
# cast_size                                                             26
# crew_size                                                             16
# director                                                    Joe Johnston
#
#                                                                    2      \
# id                                                                 15602
# title                                                   Grumpier Old Men
# tagline                Still Yelling. Still Fighting. Still Ready for...
# release_date                                                  1995-12-22
# genres                                                    Romance|Comedy
# belongs_to_collection                          Grumpy Old Men Collection
# original_language                                                     en
# budget_musd                                                          NaN
# revenue_musd                                                         NaN
# production_companies                         Warner Bros.|Lancaster Gate
# production_countries                            United States of America
# vote_count                                                          92.0
# vote_average                                                         6.5
# popularity                                                       11.7129
# runtime                                                            101.0
# overview               A family wedding reignites the ancient feud be...
# spoken_languages                                                 English
# poster_path            <img src='http://image.tmdb.org/t/p/w185//1FSX...
# cast                   Walter Matthau|Jack Lemmon|Ann-Margret|Sophia ...
# cast_size                                                              7
# crew_size                                                              4
# director                                                   Howard Deutch
#
#                                                                    3      \
# id                                                                 31357
# title                                                  Waiting to Exhale
# tagline                Friends are the people who let you be yourself...
# release_date                                                  1995-12-22
# genres                                              Comedy|Drama|Romance
# belongs_to_collection                                                NaN
# original_language                                                     en
# budget_musd                                                         16.0
# revenue_musd                                                   81.452156
# production_companies              Twentieth Century Fox Film Corporation
# production_countries                            United States of America
# vote_count                                                          34.0
# vote_average                                                         6.1
# popularity                                                      3.859495
# runtime                                                            127.0
# overview               Cheated on, mistreated and stepped on, the wom...
# spoken_languages                                                 English
# poster_path            <img src='http://image.tmdb.org/t/p/w185//4wjG...
# cast                   Whitney Houston|Angela Bassett|Loretta Devine|...
# cast_size                                                             10
# crew_size                                                             10
# director                                                 Forest Whitaker
#
#                                                                    4      \
# id                                                                 11862
# title                                        Father of the Bride Part II
# tagline                Just When His World Is Back To Normal... He's ...
# release_date                                                  1995-02-10
# genres                                                            Comedy
# belongs_to_collection                     Father of the Bride Collection
# original_language                                                     en
# budget_musd                                                          NaN
# revenue_musd                                                   76.578911
# production_companies           Sandollar Productions|Touchstone Pictures
# production_countries                            United States of America
# vote_count                                                         173.0
# vote_average                                                         5.7
# popularity                                                      8.387519
# runtime                                                            106.0
# overview               Just when George Banks has recovered from his ...
# spoken_languages                                                 English
# poster_path            <img src='http://image.tmdb.org/t/p/w185//lf9R...
# cast                   Steve Martin|Diane Keaton|Martin Short|Kimberl...
# cast_size                                                             12
# crew_size                                                              7
# director                                                   Charles Shyer
#
#                                                                    5      \
# id                                                                   949
# title                                                               Heat
# tagline                                         A Los Angeles Crime Saga
# release_date                                                  1995-12-15
# genres                                       Action|Crime|Drama|Thriller
# belongs_to_collection                                                NaN
# original_language                                                     en
# budget_musd                                                         60.0
# revenue_musd                                                  187.436818
# production_companies       Regency Enterprises|Forward Pass|Warner Bros.
# production_countries                            United States of America
# vote_count                                                        1886.0
# vote_average                                                         7.7
# popularity                                                     17.924927
# runtime                                                            170.0
# overview               Obsessive master thief, Neil McCauley leads a ...
# spoken_languages                                         English|Español
# poster_path            <img src='http://image.tmdb.org/t/p/w185//lbf2...
# cast                   Al Pacino|Robert De Niro|Val Kilmer|Jon Voight...
# cast_size                                                             65
# crew_size                                                             71
# director                                                    Michael Mann
#
#                                                                    6      \
# id                                                                 11860
# title                                                            Sabrina
# tagline                You are cordially invited to the most surprisi...
# release_date                                                  1995-12-15
# genres                                                    Comedy|Romance
# belongs_to_collection                                                NaN
# original_language                                                     en
# budget_musd                                                         58.0
# revenue_musd                                                         NaN
# production_companies   Paramount Pictures|Scott Rudin Productions|Mir...
# production_countries                    Germany|United States of America
# vote_count                                                         141.0
# vote_average                                                         6.2
# popularity                                                      6.677277
# runtime                                                            127.0
# overview               An ugly duckling having undergone a remarkable...
# spoken_languages                                        Français|English
# poster_path            <img src='http://image.tmdb.org/t/p/w185//z1oN...
# cast                   Harrison Ford|Julia Ormond|Greg Kinnear|Angie ...
# cast_size                                                             57
# crew_size                                                             53
# director                                                  Sydney Pollack
#
#                                                                    7      \
# id                                                                 45325
# title                                                       Tom and Huck
# tagline                                           The Original Bad Boys.
# release_date                                                  1995-12-22
# genres                                     Action|Adventure|Drama|Family
# belongs_to_collection                                                NaN
# original_language                                                     en
# budget_musd                                                          NaN
# revenue_musd                                                         NaN
# production_companies                                Walt Disney Pictures
# production_countries                            United States of America
# vote_count                                                          45.0
# vote_average                                                         5.4
# popularity                                                      2.561161
# runtime                                                             97.0
# overview               A mischievous young boy, Tom Sawyer, witnesses...
# spoken_languages                                         English|Deutsch
# poster_path            <img src='http://image.tmdb.org/t/p/w185//6yox...
# cast                   Jonathan Taylor Thomas|Brad Renfro|Rachael Lei...
# cast_size                                                              7
# crew_size                                                              4
# director                                                    Peter Hewitt
#
#                                                                    8      \
# id                                                                  9091
# title                                                       Sudden Death
# tagline                                       Terror goes into overtime.
# release_date                                                  1995-12-22
# genres                                         Action|Adventure|Thriller
# belongs_to_collection                                                NaN
# original_language                                                     en
# budget_musd                                                         35.0
# revenue_musd                                                   64.350171
# production_companies   Universal Pictures|Imperial Entertainment|Sign...
# production_countries                            United States of America
# vote_count                                                         174.0
# vote_average                                                         5.5
# popularity                                                       5.23158
# runtime                                                            106.0
# overview               International action superstar Jean Claude Van...
# spoken_languages                                                 English
# poster_path            <img src='http://image.tmdb.org/t/p/w185//gV1V...
# cast                   Jean-Claude Van Damme|Powers Boothe|Dorian Har...
# cast_size                                                              6
# crew_size                                                              9
# director                                                     Peter Hyams
#
#                                                                    9      ...  \
# id                                                                   710  ...
# title                                                          GoldenEye  ...
# tagline                             No limits. No fears. No substitutes.  ...
# release_date                                                  1995-11-16  ...
# genres                                         Adventure|Action|Thriller  ...
# belongs_to_collection                              James Bond Collection  ...
# original_language                                                     en  ...
# budget_musd                                                         58.0  ...
# revenue_musd                                                  352.194034  ...
# production_companies                      United Artists|Eon Productions  ...
# production_countries             United Kingdom|United States of America  ...
# vote_count                                                        1194.0  ...
# vote_average                                                         6.6  ...
# popularity                                                     14.686036  ...
# runtime                                                            130.0  ...
# overview               James Bond must unmask the mysterious head of ...  ...
# spoken_languages                                 English|Pусский|Español  ...
# poster_path            <img src='http://image.tmdb.org/t/p/w185//z0lj...  ...
# cast                   Pierce Brosnan|Sean Bean|Izabella Scorupco|Fam...  ...
# cast_size                                                             20  ...
# crew_size                                                             46  ...
# director                                                 Martin Campbell  ...
#
#                                                                    44681  \
# id                                                                 84419
# title                                                   House of Horrors
# tagline                                              Meet...The CREEPER!
# release_date                                                  1946-03-29
# genres                                           Horror|Mystery|Thriller
# belongs_to_collection                                                NaN
# original_language                                                     en
# budget_musd                                                          NaN
# revenue_musd                                                         NaN
# production_companies                                  Universal Pictures
# production_countries                            United States of America
# vote_count                                                           8.0
# vote_average                                                         6.3
# popularity                                                      0.222814
# runtime                                                             65.0
# overview               An unsuccessful sculptor saves a madman named ...
# spoken_languages                                                 English
# poster_path            <img src='http://image.tmdb.org/t/p/w185//hWMy...
# cast                   Rondo Hatton|Robert Lowery|Virginia Grey|Bill ...
# cast_size                                                             11
# crew_size                                                             11
# director                                                  Jean Yarbrough
#
#                                                                    44682  \
# id                                                                390959
# title                                          Shadow of the Blair Witch
# tagline                                                              NaN
# release_date                                                  2000-10-22
# genres                                                    Mystery|Horror
# belongs_to_collection                                                NaN
# original_language                                                     en
# budget_musd                                                          NaN
# revenue_musd                                                         NaN
# production_companies                                                 NaN
# production_countries                                                 NaN
# vote_count                                                           2.0
# vote_average                                                         7.0
# popularity                                                      0.076061
# runtime                                                             45.0
# overview               In this true-crime documentary, we delve into ...
# spoken_languages                                                 English
# poster_path            <img src='http://image.tmdb.org/t/p/w185//q75t...
# cast                   Tony Abatemarco|Andre Brooks|Mariclare Costell...
# cast_size                                                             19
# crew_size                                                             29
# director                                                        Ben Rock
#
#                                                                    44683  \
# id                                                                289923
# title                                                The Burkittsville 7
# tagline                Do you know what happened 50 years before "The...
# release_date                                                  2000-10-03
# genres                                                            Horror
# belongs_to_collection                                                NaN
# original_language                                                     en
# budget_musd                                                          NaN
# revenue_musd                                                         NaN
# production_companies       Neptune Salad Entertainment|Pirie Productions
# production_countries                            United States of America
# vote_count                                                           1.0
# vote_average                                                         7.0
# popularity                                                       0.38645
# runtime                                                             30.0
# overview               A film archivist revisits the story of Rustin ...
# spoken_languages                                                 English
# poster_path            <img src='http://image.tmdb.org/t/p/w185//lXto...
# cast                   Monty Bane|Lucy Butler|David Grammer|Bill Dreg...
# cast_size                                                              8
# crew_size                                                              2
# director                                                        Ben Rock
#
#                                                                    44684  \
# id                                                                222848
# title                                                    Caged Heat 3000
# tagline                                                              NaN
# release_date                                                  1995-01-01
# genres                                                   Science Fiction
# belongs_to_collection                                                NaN
# original_language                                                     en
# budget_musd                                                          NaN
# revenue_musd                                                         NaN
# production_companies                               Concorde-New Horizons
# production_countries                            United States of America
# vote_count                                                           1.0
# vote_average                                                         3.5
# popularity                                                      0.661558
# runtime                                                             85.0
# overview               It's the year 3000 AD. The world's most danger...
# spoken_languages                                                 English
# poster_path            <img src='http://image.tmdb.org/t/p/w185//qyiY...
# cast                   Lisa Boyle|Kena Land|Zaneta Polard|Don Yanan|D...
# cast_size                                                             10
# crew_size                                                              6
# director                                                   Aaron Osborne
#
#                                                                    44685  \
# id                                                                 30840
# title                                                         Robin Hood
# tagline                                                              NaN
# release_date                                                  1991-05-13
# genres                                              Drama|Action|Romance
# belongs_to_collection                                                NaN
# original_language                                                     en
# budget_musd                                                          NaN
# revenue_musd                                                         NaN
# production_companies   Westdeutscher Rundfunk (WDR)|Working Title Fil...
# production_countries   Canada|Germany|United Kingdom|United States of...
# vote_count                                                          26.0
# vote_average                                                         5.7
# popularity                                                      5.683753
# runtime                                                            104.0
# overview               Yet another version of the classic epic, with ...
# spoken_languages                                                 English
# poster_path            <img src='http://image.tmdb.org/t/p/w185//rmVy...
# cast                   Patrick Bergin|Uma Thurman|David Morrissey|Jür...
# cast_size                                                              5
# crew_size                                                              9
# director                                                      John Irvin
#
#                                                                    44686  \
# id                                                                439050
# title                                                             Subdue
# tagline                       Rising and falling between a man and woman
# release_date                                                         NaN
# genres                                                      Drama|Family
# belongs_to_collection                                                NaN
# original_language                                                     fa
# budget_musd                                                          NaN
# revenue_musd                                                         NaN
# production_companies                                                 NaN
# production_countries                                                Iran
# vote_count                                                           1.0
# vote_average                                                         4.0
# popularity                                                      0.072051
# runtime                                                             90.0
# overview                     Rising and falling between a man and woman.
# spoken_languages                                                   فارسی
# poster_path            <img src='http://image.tmdb.org/t/p/w185//pfC8...
# cast                             Leila Hatami|Kourosh Tahami|Elham Korda
# cast_size                                                              3
# crew_size                                                              9
# director                                                Hamid Nematollah
#
#                                                                    44687  \
# id                                                                111109
# title                                                Century of Birthing
# tagline                                                              NaN
# release_date                                                  2011-11-17
# genres                                                             Drama
# belongs_to_collection                                                NaN
# original_language                                                     tl
# budget_musd                                                          NaN
# revenue_musd                                                         NaN
# production_companies                                         Sine Olivia
# production_countries                                         Philippines
# vote_count                                                           3.0
# vote_average                                                         9.0
# popularity                                                      0.178241
# runtime                                                            360.0
# overview               An artist struggles to finish his work while a...
# spoken_languages                                                     NaN
# poster_path            <img src='http://image.tmdb.org/t/p/w185//xZkm...
# cast                   Angel Aquino|Perry Dizon|Hazel Orencio|Joel To...
# cast_size                                                             11
# crew_size                                                              6
# director                                                        Lav Diaz
#
#                                                                    44688  \
# id                                                                 67758
# title                                                           Betrayal
# tagline                                           A deadly game of wits.
# release_date                                                  2003-08-01
# genres                                             Action|Drama|Thriller
# belongs_to_collection                                                NaN
# original_language                                                     en
# budget_musd                                                          NaN
# revenue_musd                                                         NaN
# production_companies                             American World Pictures
# production_countries                            United States of America
# vote_count                                                           6.0
# vote_average                                                         3.8
# popularity                                                      0.903007
# runtime                                                             90.0
# overview               When one of her hits goes wrong, a professiona...
# spoken_languages                                                 English
# poster_path            <img src='http://image.tmdb.org/t/p/w185//eGga...
# cast                   Erika Eleniak|Adam Baldwin|Julie du Page|James...
# cast_size                                                             15
# crew_size                                                              5
# director                                                  Mark L. Lester
#
#                                                                    44689  \
# id                                                                227506
# title                                                   Satan Triumphant
# tagline                                                              NaN
# release_date                                                  1917-10-21
# genres                                                               NaN
# belongs_to_collection                                                NaN
# original_language                                                     en
# budget_musd                                                          NaN
# revenue_musd                                                         NaN
# production_companies                                           Yermoliev
# production_countries                                              Russia
# vote_count                                                           0.0
# vote_average                                                         NaN
# popularity                                                      0.003503
# runtime                                                             87.0
# overview               In a small town live two brothers, one a minis...
# spoken_languages                                                     NaN
# poster_path            <img src='http://image.tmdb.org/t/p/w185//aorB...
# cast                   Iwan Mosschuchin|Nathalie Lissenko|Pavel Pavlo...
# cast_size                                                              5
# crew_size                                                              2
# director                                                Yakov Protazanov
#
#                                                                    44690
# id                                                                461257
# title                                                           Queerama
# tagline                                                              NaN
# release_date                                                  2017-06-09
# genres                                                               NaN
# belongs_to_collection                                                NaN
# original_language                                                     en
# budget_musd                                                          NaN
# revenue_musd                                                         NaN
# production_companies                                                 NaN
# production_countries                                      United Kingdom
# vote_count                                                           0.0
# vote_average                                                         NaN
# popularity                                                      0.163015
# runtime                                                             75.0
# overview               50 years after decriminalisation of homosexual...
# spoken_languages                                                 English
# poster_path            <img src='http://image.tmdb.org/t/p/w185//oxFE...
# cast                                                                 NaN
# cast_size                                                              0
# crew_size                                                              1
# director                                                   Daisy Asquith
#
# [22 rows x 44691 columns]

# %%
movie_df.director.value_counts().head()
# Out:
# John Ford           66
# Michael Curtiz      65
# Werner Herzog       54
# Alfred Hitchcock    53
# Georges Méliès      49
# Name: director, dtype: int64

# %% [markdown]
# ## The best and the worst movies...

# %% [markdown]
# 2. __Filter__ the Dataset and __find the best/worst n Movies__ with the

# %% [markdown]
# - Highest Revenue
# - Highest Budget
# - Highest Profit (=Revenue - Budget)
# - Lowest Profit (=Revenue - Budget)
# - Highest Return on Investment (=Revenue / Budget) (only movies with Budget >= 10)
# - Lowest Return on Investment (=Revenue / Budget) (only movies with Budget >= 10)
# - Highest number of Votes
# - Highest Rating (only movies with 10 or more Ratings)
# - Lowest Rating (only movies with 10 or more Ratings)
# - Highest Popularity

# %% [markdown]
# __Define__ an appropriate __user-defined function__ to reuse code.

# %% [markdown]
# __Movies Top 5 - Highest Revenue__

# %%
movie_df.sort_values(by='revenue_musd',ascending=False)[['title','revenue_musd','release_date']].head(5)
# Out:
#                               title  revenue_musd release_date
# 14448                        Avatar   2787.965087   2009-12-10
# 26265  Star Wars: The Force Awakens   2068.223624   2015-12-15
# 1620                        Titanic   1845.034188   1997-11-18
# 17669                  The Avengers   1519.557910   2012-04-25
# 24812                Jurassic World   1513.528810   2015-06-09

# %% [markdown]
# __Movies Top 5 - Highest Budget__

# %%
movie_df.sort_values(by='budget_musd',ascending=False)[['title','budget_musd']].head(5)
# Out:
#                                              title  budget_musd
# 16986  Pirates of the Caribbean: On Stranger Tides        380.0
# 11743     Pirates of the Caribbean: At World's End        300.0
# 26268                      Avengers: Age of Ultron        280.0
# 10985                             Superman Returns        270.0
# 18517                                  John Carter        260.0

# %% [markdown]
# __Movies Top 5 - Highest Profit__

# %%
movie_df['profit_musd'] = movie_df.revenue_musd - movie_df.budget_musd

# %%
movie_df.sort_values(by='profit_musd',ascending=False)[['title','profit_musd','release_date']].head(5)
# Out:
#                               title  profit_musd release_date
# 14448                        Avatar  2550.965087   2009-12-10
# 26265  Star Wars: The Force Awakens  1823.223624   2015-12-15
# 1620                        Titanic  1645.034188   1997-11-18
# 24812                Jurassic World  1363.528810   2015-06-09
# 28501                     Furious 7  1316.249360   2015-04-01

# %% [markdown]
# __Movies Top 5 - Lowest Profit__

# %%
movie_df.sort_values(by='profit_musd',ascending=True)[['title','profit_musd','release_date']].head(5)
# Out:
#                                              title  profit_musd release_date
# 20959                              The Lone Ranger  -165.710090   2013-07-03
# 7164                                     The Alamo  -119.180039   2004-04-07
# 16659                              Mars Needs Moms  -111.007242   2011-03-09
# 43611  Valerian and the City of a Thousand Planets  -107.447384   2017-07-20
# 2684                              The 13th Warrior   -98.301101   1999-08-27

# %% [markdown]
# __Movies Top 5 - Highest ROI__

# %%
movie_df['ROI'] = movie_df.revenue_musd / movie_df.budget_musd

# %%
movie_df[movie_df['budget_musd']>=10].sort_values(by='ROI',ascending=False)[['title','ROI','budget_musd','release_date']].head(5)
# Out:
#                             title        ROI  budget_musd release_date
# 1055   E.T. the Extra-Terrestrial  75.520507         10.5   1982-04-03
# 255                     Star Wars  70.490728         11.0   1977-05-25
# 588                  Pretty Woman  33.071429         14.0   1990-03-23
# 18300            The Intouchables  32.806221         13.0   2011-11-02
# 1144      The Empire Strikes Back  29.911111         18.0   1980-05-17

# %% [markdown]
# __Movies Top 5 - Lowest ROI__

# %%
movie_df[movie_df['budget_musd']>=10].sort_values(by='ROI',ascending=True)[['title','ROI','budget_musd','release_date']].head(5)
# Out:
#                  title           ROI  budget_musd release_date
# 6955   Chasing Liberty  5.217391e-07         23.0   2004-01-09
# 8041       The Cookout  7.500000e-07         16.0   2004-09-03
# 17381         Deadfall  1.800000e-06         10.0   1993-10-08
# 6678        In the Cut  1.916667e-06         12.0   2003-09-09
# 20015    The Samaritan  2.100833e-04         12.0   2012-03-02

# %% [markdown]
# __Movies Top 5 - Most Votes__

# %%
movie_df.sort_values(by='vote_count',ascending=False)[['title','vote_count','release_date']].head(5)
# Out:
#                  title  vote_count release_date
# 15368        Inception     14075.0   2010-07-14
# 12396  The Dark Knight     12269.0   2008-07-16
# 14448           Avatar     12114.0   2009-12-10
# 17669     The Avengers     12000.0   2012-04-25
# 26272         Deadpool     11444.0   2016-02-09

# %% [markdown]
# __Movies Top 5 - Highest Rating__

# %%
movie_df[movie_df.vote_count >= 1000].sort_values(by='vote_average',ascending=False)[['title','vote_average','vote_count','release_date']].head(5)
# Out:
#                              title  vote_average  vote_count release_date
# 826                  The Godfather           8.5      6024.0   1972-03-14
# 39639                   Your Name.           8.5      1030.0   2016-08-26
# 313       The Shawshank Redemption           8.5      8358.0   1994-09-23
# 291                   Pulp Fiction           8.3      8670.0   1994-09-10
# 1174   Once Upon a Time in America           8.3      1104.0   1984-02-16

# %% [markdown]
# __Movies Top 5 - Lowest Rating__

# %%
movie_df[movie_df.vote_count >= 10].sort_values(by='vote_average',ascending=True)[['title','vote_average','vote_count','release_date']].head(5)
# Out:
#                                  title  vote_average  vote_count release_date
# 41602             Call Me by Your Name           0.0        18.0   2017-10-27
# 30618   Extinction: Nature Has Evolved           0.0        10.0   2017-03-10
# 43576  How to Talk to Girls at Parties           0.0        10.0   2017-12-27
# 25418                      Santa Claus           1.6        12.0   1959-11-26
# 7030          The Beast of Yucca Flats           1.6        18.0   1961-06-02

# %% [markdown]
# __Movies Top 5 - Most Popular__

# %%
movie_df.sort_values(by='popularity',ascending=False)[['title','popularity','release_date']].head(5)
# Out:
#                       title  popularity release_date
# 30330               Minions  547.488298   2015-06-17
# 32927          Wonder Woman  294.337037   2017-05-30
# 41556  Beauty and the Beast  287.253654   2017-03-16
# 42940           Baby Driver  228.032744   2017-06-28
# 24187            Big Hero 6  213.849907   2014-10-24

# %% [markdown]
# ## Find your next Movie

# %% [markdown]
# 3. __Filter__ the Dataset for movies that meet the following conditions:

# %% [markdown]
# __Search 1: Science Fiction Action Movie with Bruce Willis (sorted from high to low Rating)__

# %% [markdown]
# __Search 2: Movies with Uma Thurman and directed by Quentin Tarantino (sorted from short to long runtime)__

# %% [markdown]
# __Search 3: Most Successful Pixar Studio Movies between 2010 and 2015 (sorted from high to low Revenue)__

# %% [markdown]
# __Search 4: Action or Thriller Movie with original language English and minimum Rating of 7.5 (most recent movies first)__

# %% [markdown]
# ## Search 1: Science Fiction Action Movie with Bruce Willis (sorted from high to low Rating)

# %%
def search_movie(search_params,df):
    # [{'col':'....','val':'....'}]
    mask = np.full(df.shape[0], True)
    for search_param in search_params:
        col_name = search_param['col']
        search_str = search_param['val']
        mask = mask & (df[col_name].str.match(f'.*{search_str}.*',na=False))
    return df[mask]

def search_movie_or(search_params,df):
    # [{'col':'....','val':'....'}]
    mask = np.full(df.shape[0], False)
    for search_param in search_params:
        col_name = search_param['col']
        search_str = search_param['val']
        mask = mask | (df[col_name].str.match(f'.*{search_str}.*',na=False))
    return df[mask]

# %%
(search_movie([{'col':'genres','val':'Science Fiction'},{'col':'cast','val':'Bruce Willis'}],movie_df)
    .sort_values(by='vote_average',ascending=False)).head(5)
# Out:
#           id              title  \
# 31        63     Twelve Monkeys
# 1448      18  The Fifth Element
# 3836    9741        Unbreakable
# 19218  59967             Looper
# 1786      95         Armageddon
#
#                                                  tagline release_date  \
# 31                                The future is history.   1995-12-29
# 1448                      There is no future without it.   1997-05-07
# 3836          Some things are only revealed by accident.   2000-11-13
# 19218        Hunted By Your Future, Haunted By Your Past   2012-09-26
# 1786   The Earth's Darkest Day Will Be Man's Finest Hour   1998-07-01
#
#                                                   genres  \
# 31                      Science Fiction|Thriller|Mystery
# 1448   Adventure|Fantasy|Action|Thriller|Science Fiction
# 3836                      Science Fiction|Thriller|Drama
# 19218                    Action|Thriller|Science Fiction
# 1786           Action|Thriller|Science Fiction|Adventure
#
#       belongs_to_collection original_language  budget_musd  revenue_musd  \
# 31                      NaN                en         29.5    168.840000
# 1448                    NaN                en         90.0    263.920180
# 3836                    NaN                en         75.0    248.118121
# 19218                   NaN                en         30.0     47.042000
# 1786                    NaN                en        140.0    553.799566
#
#                                     production_companies  ... runtime  \
# 31       Universal Pictures|Atlas Entertainment|Classico  ...   129.0
# 1448                           Columbia Pictures|Gaumont  ...   126.0
# 3836   Limited Edition Productions Inc.|Touchstone Pi...  ...   106.0
# 19218  Endgame Entertainment|FilmDistrict|DMG Enterta...  ...   118.0
# 1786   Jerry Bruckheimer Films|Touchstone Pictures|Va...  ...   151.0
#
#                                                 overview  \
# 31     In the year 2035, convict James Cole reluctant...
# 1448   In 2257, a taxi driver is unintentionally give...
# 3836   An ordinary man makes an extraordinary discove...
# 19218  In the futuristic action thriller Looper, time...
# 1786   When an asteroid threatens to collide with Ear...
#
#               spoken_languages  \
# 31            English|Français
# 1448   English|svenska|Deutsch
# 3836                   English
# 19218                  English
# 1786           English|Pусский
#
#                                              poster_path  \
# 31     <img src='http://image.tmdb.org/t/p/w185//2F9K...
# 1448   <img src='http://image.tmdb.org/t/p/w185//fPtl...
# 3836   <img src='http://image.tmdb.org/t/p/w185//kXkV...
# 19218  <img src='http://image.tmdb.org/t/p/w185//sNjL...
# 1786   <img src='http://image.tmdb.org/t/p/w185//fMtO...
#
#                                                     cast cast_size crew_size  \
# 31     Bruce Willis|Madeleine Stowe|Brad Pitt|Christo...        65       151
# 1448   Bruce Willis|Gary Oldman|Ian Holm|Milla Jovovi...       114       134
# 3836   Bruce Willis|Samuel L. Jackson|Robin Wright|Sp...        40        56
# 19218  Joseph Gordon-Levitt|Bruce Willis|Emily Blunt|...        34        42
# 1786   Bruce Willis|Billy Bob Thornton|Ben Affleck|Li...        67       108
#
#                  director profit_musd       ROI
# 31          Terry Gilliam  139.340000  5.723390
# 1448           Luc Besson  173.920180  2.932446
# 3836   M. Night Shyamalan  173.118121  3.308242
# 19218        Rian Johnson   17.042000  1.568067
# 1786          Michael Bay  413.799566  3.955711
#
# [5 rows x 24 columns]

# %% [markdown]
# ## Search 2: Movies with Uma Thurman and directed by Quentin Tarantino (sorted from short to long runtime)

# %%
(search_movie([{'col':'director','val':'Quentin Tarantino'},{'col':'cast','val':'Uma Thurman'}],movie_df)
    .sort_values(by='runtime',ascending=True))[['title','director','cast','runtime']]
# Out:
#                   title           director  \
# 6667  Kill Bill: Vol. 1  Quentin Tarantino
# 7208  Kill Bill: Vol. 2  Quentin Tarantino
# 291        Pulp Fiction  Quentin Tarantino
#
#                                                    cast  runtime
# 6667  Uma Thurman|Lucy Liu|Vivica A. Fox|Daryl Hanna...    111.0
# 7208  Uma Thurman|David Carradine|Daryl Hannah|Micha...    136.0
# 291   John Travolta|Samuel L. Jackson|Uma Thurman|Br...    154.0

# %% [markdown]
# ## Search 3: Most Successful Pixar Studio Movies between 2010 and 2015 (sorted from high to low Revenue)

# %%
pixar_movies = search_movie([{'col':'production_companies','val':'Pixar Animation Studios'}],movie_df)

# %%
(search_movie_or([{'col':'release_date','val':'2010'},{'col':'release_date','val':'2015'}],pixar_movies)
.sort_values(by='revenue_musd',ascending=False))[['title','production_companies','release_date','revenue_musd']]
# Out:
#                      title                          production_companies  \
# 15236          Toy Story 3  Walt Disney Pictures|Pixar Animation Studios
# 29957           Inside Out  Walt Disney Pictures|Pixar Animation Studios
# 30388    The Good Dinosaur  Walt Disney Pictures|Pixar Animation Studios
# 16392          Day & Night  Walt Disney Pictures|Pixar Animation Studios
# 31803                 Lava                       Pixar Animation Studios
# 34560  Sanjay's Super Team                       Pixar Animation Studios
# 40675  Riley's First Date?  Walt Disney Pictures|Pixar Animation Studios
#
#       release_date  revenue_musd
# 15236   2010-06-16   1066.969703
# 29957   2015-06-09    857.611174
# 30388   2015-11-14    331.926147
# 16392   2010-06-17           NaN
# 31803   2015-06-21           NaN
# 34560   2015-11-25           NaN
# 40675   2015-11-03           NaN

# %% [markdown]
# ## Search 4: Action or Thriller Movie with original language English and minimum Rating of 7.5 (most recent movies first)

# %%
movie_df['release_ts'] = movie_df.release_date.apply(lambda date_str: pd.Timestamp(date_str))

# %%
action_thriller_df = search_movie_or([{'col':'genres','val':'Action'},{'col':'genres','val':'Thriller'}],movie_df)

# %%
(action_thriller_df[(action_thriller_df['original_language'] == 'en') & (action_thriller_df['vote_average'] >= 7.5)]
    .sort_values(by='release_ts',ascending=False))[['title','genres','original_language','vote_average','release_date']]
# Out:
#                                 title  \
# 44490                   Descendants 2
# 43941                         Dunkirk
# 42624               The Book of Henry
# 26273  Guardians of the Galaxy Vol. 2
# 43467                     Revengeance
# ...                               ...
# 11135                   The Music Box
# 8268                         Scarface
# 8255              Steamboat Bill, Jr.
# 2879                      The General
# 34547        Bardelys the Magnificent
#
#                                               genres original_language  \
# 44490  TV Movie|Family|Action|Comedy|Music|Adventure                en
# 43941              Action|Drama|History|Thriller|War                en
# 42624                           Thriller|Drama|Crime                en
# 26273        Action|Adventure|Comedy|Science Fiction                en
# 43467                        Comedy|Action|Animation                en
# ...                                              ...               ...
# 11135                                  Action|Comedy                en
# 8268           Action|Adventure|Crime|Drama|Thriller                en
# 8255                                   Action|Comedy                en
# 2879                   Action|Adventure|Comedy|Drama                en
# 34547                           Action|Drama|Romance                en
#
#        vote_average release_date
# 44490           7.5   2017-07-21
# 43941           7.5   2017-07-19
# 42624           7.6   2017-06-16
# 26273           7.6   2017-04-19
# 43467           8.0   2017-04-05
# ...             ...          ...
# 11135           7.5   1932-04-16
# 8268            7.5   1932-04-09
# 8255            7.9   1928-02-14
# 2879            8.0   1926-12-31
# 34547           8.0   1926-09-30
#
# [302 rows x 5 columns]

# %% [markdown]
# ## Are Franchises more successful?

# %% [markdown]
# 4. __Analyze__ the Dataset and __find out whether Franchises (Movies that belong to a collection) are more successful than stand-alone movies__ in terms of:

# %% [markdown]
# - mean revenue
# - median Return on Investment
# - mean budget raised
# - mean popularity
# - mean rating

# %% [markdown]
# hint: use groupby()

# %% [markdown]
# __Franchise vs. Stand-alone: Average Revenue__

# %%
movie_df['has_franchise'] = ~movie_df.belongs_to_collection.isna()

# %%
movie_df.groupby('has_franchise').agg({'revenue_musd':['mean']})
# Out:
#               revenue_musd
#                       mean
# has_franchise
# False            44.742814
# True            165.708193

# %% [markdown]
# __Franchise vs. Stand-alone: Return on Investment / Profitability (median)__

# %%
movie_df.groupby('has_franchise').agg({'ROI':['median']})
# Out:
#                     ROI
#                  median
# has_franchise
# False          1.619699
# True           3.709195

# %% [markdown]
# __Franchise vs. Stand-alone: Average Budget__

# %%
movie_df.groupby('has_franchise').agg({'budget_musd':['mean']})
# Out:
#               budget_musd
#                      mean
# has_franchise
# False           18.047741
# True            38.319847

# %% [markdown]
# __Franchise vs. Stand-alone: Average Popularity__

# %%
movie_df.groupby('has_franchise').agg({'popularity':['mean']})
# Out:
#               popularity
#                     mean
# has_franchise
# False           2.592726
# True            6.245051

# %% [markdown]
# __Franchise vs. Stand-alone: Average Rating__

# %%
movie_df.groupby('has_franchise').agg({'vote_average':['mean']})
# Out:
#                    mean
# has_franchise
# False          6.008787
# True           5.956806

# %% [markdown]
# ## Most Successful Franchises

# %% [markdown]
# 5. __Find__ the __most successful Franchises__ in terms of

# %% [markdown]
# - __total number of movies__
# - __total & mean budget__
# - __total & mean revenue__
# - __mean rating__

# %% [markdown]
# ### total number of movies

# %%
(movie_df[movie_df.has_franchise == True].groupby('belongs_to_collection').agg({'title':['count']})['title']).sort_values(by='count',ascending=False).head(10)
# Out:
#                                         count
# belongs_to_collection
# The Bowery Boys                            29
# Totò Collection                            27
# James Bond Collection                      26
# Zatôichi: The Blind Swordsman              26
# The Carry On Collection                    25
# Charlie Chan (Sidney Toler) Collection     21
# Pokémon Collection                         20
# Godzilla (Showa) Collection                16
# Dragon Ball Z (Movie) Collection           15
# Charlie Chan (Warner Oland) Collection     15

# %% [markdown]
# ## total budget

# %%
(movie_df[movie_df.has_franchise == True].groupby('belongs_to_collection').agg({'budget_musd':['sum']})['budget_musd']).sort_values(by='sum',ascending=False).head(10)
# Out:
#                                          sum
# belongs_to_collection
# James Bond Collection                1539.65
# Harry Potter Collection              1280.00
# Pirates of the Caribbean Collection  1250.00
# The Fast and the Furious Collection  1009.00
# X-Men Collection                      983.00
# Transformers Collection               965.00
# Star Wars Collection                  854.35
# The Hobbit Collection                 750.00
# The Terminator Collection             661.40
# Mission: Impossible Collection        650.00

# %% [markdown]
# ### mean budget

# %%
(movie_df[movie_df.has_franchise == True].groupby('belongs_to_collection').agg({'budget_musd':['mean','sum','count']})['budget_musd']).sort_values(by='mean',ascending=False).head(10)
# Out:
#                                       mean     sum  count
# belongs_to_collection
# Tangled Collection                   260.0   260.0      1
# The Avengers Collection              250.0   500.0      2
# Pirates of the Caribbean Collection  250.0  1250.0      5
# The Hobbit Collection                250.0   750.0      3
# Man of Steel Collection              237.5   475.0      2
# Avatar Collection                    237.0   237.0      1
# The Amazing Spider-Man Collection    207.5   415.0      2
# World War Z Collection               200.0   200.0      1
# Spider-Man Collection                199.0   597.0      3
# The Dark Knight Collection           195.0   585.0      3

# %% [markdown]
# ### total & mean revenue

# %%
(movie_df[movie_df.has_franchise == True].groupby('belongs_to_collection').agg({'revenue_musd':['sum','mean','count']})['revenue_musd']).sort_values(by='sum',ascending=False).head(10)
# Out:
#                                              sum        mean  count
# belongs_to_collection
# Harry Potter Collection              7707.367425  963.420928      8
# Star Wars Collection                 7434.494790  929.311849      8
# James Bond Collection                7106.970239  273.345009     26
# The Fast and the Furious Collection  5125.098793  640.637349      8
# Pirates of the Caribbean Collection  4521.576826  904.315365      5
# Transformers Collection              4366.101244  873.220249      5
# Despicable Me Collection             3691.070216  922.767554      4
# The Twilight Collection              3342.107290  668.421458      5
# Ice Age Collection                   3216.708553  643.341711      5
# Jurassic Park Collection             3031.484143  757.871036      4

# %%
(movie_df[movie_df.has_franchise == True].groupby('belongs_to_collection').agg({'revenue_musd':['mean','sum','count']})['revenue_musd']).sort_values(by='mean',ascending=False).head(10)
# Out:
#                                             mean          sum  count
# belongs_to_collection
# Avatar Collection                    2787.965087  2787.965087      1
# The Avengers Collection              1462.480802  2924.961604      2
# Frozen Collection                    1274.219009  1274.219009      1
# Finding Nemo Collection               984.453213  1968.906425      2
# The Hobbit Collection                 978.507785  2935.523356      3
# The Lord of the Rings Collection      972.181581  2916.544743      3
# Harry Potter Collection               963.420928  7707.367425      8
# Star Wars Collection                  929.311849  7434.494790      8
# Despicable Me Collection              922.767554  3691.070216      4
# Pirates of the Caribbean Collection   904.315365  4521.576826      5

# %% [markdown]
# ### mean rating

# %%
(movie_df[movie_df.has_franchise == True].groupby('belongs_to_collection').agg({'vote_average':['mean','sum','count']})['vote_average']).sort_values(by='mean',ascending=False).head(10)
# Out:
#                                          mean   sum  count
# belongs_to_collection
# Argo Collection                      9.300000   9.3      1
# Kenji Misumi's Trilogy of the Sword  9.000000   9.0      1
# Dreileben                            9.000000   9.0      1
# Bloodfight                           9.000000   9.0      1
# Алиса в стране чудес (Коллекция)     8.700000   8.7      1
# We Were Here                         8.650000  17.3      2
# Kizumonogatari                       8.633333  25.9      3
# Glass Tiger collection               8.500000   8.5      1
# Spirits' Homecoming Collection       8.500000   8.5      1
# The Nigger Charley Collection        8.500000   8.5      1

# %% [markdown]
# ## Most Successful Directors

# %% [markdown]
# 6. __Find__ the __most successful Directors__ in terms of

# %% [markdown]
# - __total number of movies__
# - __total revenue__
# - __mean rating__

# %%
dir_df = movie_df.groupby('director').agg({'id':['count'],'revenue_musd':['sum'],'vote_average':['mean']})
dir_df
# Out:
#                        id revenue_musd vote_average
#                     count          sum         mean
# director
#  Dale Trevillion\t      2     0.000000          4.0
#  Davide Manuli          1     0.000000          6.9
#  E.W. Swackhamer        1     0.000000          5.9
#  Vitaliy Vorobyov       1     0.000000          5.5
#  Yeon Sang-Ho           4     2.129768          6.6
# ...                   ...          ...          ...
# Ярополк Лапшин          1     0.000000         10.0
# پیمان معادی             1     0.000000          6.0
# 塩谷 直義                   1     0.000000          7.2
# 杰森·莫玛                   1     0.000000          5.8
# 진모영                     1     0.000000          6.0
#
# [17349 rows x 3 columns]

# %%
dir_df.nlargest(10,('id','count'))
# Out:
#                     id revenue_musd vote_average
#                  count          sum         mean
# director
# John Ford           66    85.170757     6.381818
# Michael Curtiz      65    37.817500     5.998246
# Werner Herzog       54    24.572580     6.805556
# Alfred Hitchcock    53   250.107584     6.639623
# Georges Méliès      49     0.000000     5.934694
# Woody Allen         49   993.970588     6.691837
# Jean-Luc Godard     46     0.867433     6.804348
# Sidney Lumet        46   294.522734     6.576744
# Charlie Chaplin     44    26.519181     6.540909
# Raoul Walsh         43     1.213880     6.004762

# %%
dir_df.nlargest(10,('revenue_musd','sum'))
# Out:
#                      id revenue_musd vote_average
#                   count          sum         mean
# director
# Steven Spielberg     33  9256.621422     6.893939
# Peter Jackson        13  6528.244659     7.138462
# Michael Bay          13  6437.466781     6.392308
# James Cameron        11  5900.610310     6.927273
# David Yates           9  5334.563196     6.700000
# Christopher Nolan    11  4747.408665     7.618182
# Robert Zemeckis      19  4138.233542     6.794737
# Tim Burton           21  4032.916124     6.733333
# Ridley Scott         24  3917.529240     6.604167
# Chris Columbus       15  3866.836869     6.440000

# %%
dir_df.nlargest(10,('vote_average','mean'))
# Out:
#                         id revenue_musd vote_average
#                      count          sum         mean
# director
# A.W. Vidmer              1          0.0         10.0
# Amy Schatz               1          0.0         10.0
# Ana Poliak               1          0.0         10.0
# Andrew Bowser            1          0.0         10.0
# Andrew Napier            1          0.0         10.0
# Antonis Sotiropoulos     1          0.0         10.0
# Barry Bruce              1          0.0         10.0
# Brandon Chesbro          1          0.0         10.0
# Brett M. Butler          1          0.0         10.0
# Brian Skeet              1          0.0         10.0

# %% [markdown]
# ## Most Successful Actors

# %% [markdown]
# 6. __Find__ the __most successful Actors__ in terms of

# %% [markdown]
# - __total number of movies__
# - __total revenue__
# - __mean rating__

# %%
# movie_df.set_index('id',inplace=True)
actors_df = movie_df.cast.dropna().str.split('|',expand=True).stack().reset_index(level=1,drop=True).to_frame()
actors_df = actors_df.applymap(lambda x:x.strip())

# %%
actors_df.columns = ['actor_name']
actors_df
# Out:
#                actor_name
# id
# 862             Tom Hanks
# 862             Tim Allen
# 862           Don Rickles
# 862            Jim Varney
# 862         Wallace Shawn
# ...                   ...
# 227506   Iwan Mosschuchin
# 227506  Nathalie Lissenko
# 227506       Pavel Pavlov
# 227506  Aleksandr Chabrov
# 227506        Vera Orlova
#
# [557703 rows x 1 columns]

# %%
actors_df = actors_df.merge(movie_df,how='left',left_index=True,right_index=True)

# %%
actors_df.groupby('actor_name').agg({'title':['count']})['title'].sort_values(by='count',ascending=False)
# Out:
#                    count
# actor_name
# Bess Flowers         240
# Christopher Lee      148
# John Wayne           125
# Samuel L. Jackson    122
# Michael Caine        110
# ...                  ...
# James Weicht           1
# James Welch            1
# James Wellington       1
# James Welsh            1
# 조병만                    1
#
# [201474 rows x 1 columns]

# %%
actors_df.groupby('actor_name').agg({'revenue_musd':['sum']})['revenue_musd'].sort_values(by='sum',ascending=False)
# Out:
#                             sum
# actor_name
# Stan Lee           19414.957555
# Samuel L. Jackson  17109.620672
# Warwick Davis      13256.032188
# Frank Welker       13044.152470
# John Ratzenberger  12596.126073
# ...                         ...
# Jankidas               0.000000
# Janko Brett            0.000000
# Janko Cekic            0.000000
# Janko Rakoš            0.000000
# 조병만                    0.000000
#
# [201474 rows x 1 columns]

# %%
actors_df.groupby('actor_name').agg({'vote_average':['mean']})['vote_average'].sort_values(by='mean',ascending=False)
# Out:
#                    mean
# actor_name
# József Ruszt       10.0
# Jamie Zevallos     10.0
# Sarah Pickering    10.0
# Judy Foster        10.0
# Mario Cunha        10.0
# ...                 ...
# Дмитрий Писаренко   NaN
# Манолис Сорманн     NaN
# Манос Вакусис       NaN
# Теодосис Заннис     NaN
# هستی مهدوی‌فر       NaN
#
# [201474 rows x 1 columns]

# %%
actor_eval = actors_df.groupby('actor_name').agg({'title':['count'],'revenue_musd':['sum'],'vote_average':['mean']})
actor_eval
# Out:
#                      title revenue_musd vote_average
#                      count          sum         mean
# actor_name
# "Elliot"                 1     0.000000       6.6000
# "Freeway" Ricky Ross     1     0.000000       6.8000
# "Jamez"                  1     0.000000       6.6000
# "Lil' Mikey" Davis       1     0.282448       5.7000
# "Weird Al" Yankovic     10   205.402057       6.0400
# ...                    ...          ...          ...
# 长泽雅美                    11     0.346485       6.4000
# 陳美貞                      1    83.061158       7.0000
# 高桥一生                     8   333.108461       6.7375
# 강계열                      1     0.000000       6.0000
# 조병만                      1     0.000000       6.0000
#
# [201474 rows x 3 columns]

# %%
actor_eval.nlargest(10,('title','count'))
# Out:
#                   title  revenue_musd vote_average
#                   count           sum         mean
# actor_name
# Bess Flowers        240    368.913259     6.184186
# Christopher Lee     148   9417.047887     5.910204
# John Wayne          125    236.094000     5.712097
# Samuel L. Jackson   122  17109.620672     6.266116
# Michael Caine       110   8053.404838     6.269444
# Gérard Depardieu    109   1247.608953     6.053211
# John Carradine      109    255.839586     5.546667
# Donald Sutherland   108   5390.766679     6.233962
# Jackie Chan         108   4699.185933     6.275701
# Frank Welker        107  13044.152470     6.310377

# %%
actor_eval.nlargest(10,('revenue_musd','sum'))
# Out:
#                   title  revenue_musd vote_average
#                   count           sum         mean
# actor_name
# Stan Lee             48  19414.957555     6.513043
# Samuel L. Jackson   122  17109.620672     6.266116
# Warwick Davis        34  13256.032188     6.294118
# Frank Welker        107  13044.152470     6.310377
# John Ratzenberger    46  12596.126073     6.484444
# Jess Harnell         35  12234.608163     6.435294
# Hugo Weaving         40  11027.578473     6.473684
# Ian McKellen         44  11015.592318     6.353488
# Johnny Depp          69  10653.760641     6.440580
# Alan Rickman         45  10612.625348     6.715556

# %%
actor_eval.nlargest(10,('vote_average','mean'))
# Out:
#                    title revenue_musd vote_average
#                    count          sum         mean
# actor_name
# A.B. Imeson            1          0.0         10.0
# Aakar Kaushik          1          0.0         10.0
# Adam Saleh             1          0.0         10.0
# Adnan Koç              1          0.0         10.0
# Agnese Civle           1          0.0         10.0
# Agoritsa Oikonomou     1          0.0         10.0
# Ahuva Keren            1          0.0         10.0
# Aigars Apinis          1          0.0         10.0
# Al Mackenzie           1          0.0         10.0
# Alan Gibson            1          0.0         10.0

# %% [markdown]
# ## Most Successful Genres

# %% [markdown]
# 6. __Find__ the __most successful Genres__ in terms of

# %% [markdown]
# - __total profit__
# - __total revenue__
# - __mean ROI__
# - __mean rating__

# %%
genre_df = movie_df.genres.dropna().str.split('|',expand=True)
genre_df
# Out:
#                       0        1         2     3     4     5     6     7
# id
# 862           Animation   Comedy    Family  None  None  None  None  None
# 8844          Adventure  Fantasy    Family  None  None  None  None  None
# 15602           Romance   Comedy      None  None  None  None  None  None
# 31357            Comedy    Drama   Romance  None  None  None  None  None
# 11862            Comedy     None      None  None  None  None  None  None
# ...                 ...      ...       ...   ...   ...   ...   ...   ...
# 222848  Science Fiction     None      None  None  None  None  None  None
# 30840             Drama   Action   Romance  None  None  None  None  None
# 439050            Drama   Family      None  None  None  None  None  None
# 111109            Drama     None      None  None  None  None  None  None
# 67758            Action    Drama  Thriller  None  None  None  None  None
#
# [42586 rows x 8 columns]

# %%
genre_df = genre_df.stack().reset_index(level=1,drop=True).to_frame()
genre_df
# Out:
#                 0
# id
# 862     Animation
# 862        Comedy
# 862        Family
# 8844    Adventure
# 8844      Fantasy
# ...           ...
# 439050     Family
# 111109      Drama
# 67758      Action
# 67758       Drama
# 67758    Thriller
#
# [90225 rows x 1 columns]

# %%
genre_df.columns = ['genre_name']

# %%
genre_df
# Out:
#        genre_name
# id
# 862     Animation
# 862        Comedy
# 862        Family
# 8844    Adventure
# 8844      Fantasy
# ...           ...
# 439050     Family
# 111109      Drama
# 67758      Action
# 67758       Drama
# 67758    Thriller
#
# [90225 rows x 1 columns]

# %%
genre_df = genre_df.merge(movie_df,how='left',left_index=True,right_index=True)

# %%
genre_df
# Out:
#        genre_name                             title  \
# id
# 2           Drama                             Ariel
# 2           Crime                             Ariel
# 3           Drama               Shadows in Paradise
# 3          Comedy               Shadows in Paradise
# 5           Crime                        Four Rooms
# ...           ...                               ...
# 468343    Romance          Silja - nuorena nukkunut
# 468707    Romance  Thick Lashes of Lauri Mäntyvaara
# 468707     Comedy  Thick Lashes of Lauri Mäntyvaara
# 469172    Fantasy   Manuel on the Island of Wonders
# 469172      Drama   Manuel on the Island of Wonders
#
#                                                   tagline release_date  \
# id
# 2                                                     NaN   1988-10-21
# 2                                                     NaN   1988-10-21
# 3                                                     NaN   1986-10-16
# 3                                                     NaN   1986-10-16
# 5       Twelve outrageous guests. Four scandalous requ...   1995-12-09
# ...                                                   ...          ...
# 468343                                                NaN   1956-01-01
# 468707                                                NaN   2017-07-28
# 468707                                                NaN   2017-07-28
# 469172                                                NaN   1984-08-02
# 469172                                                NaN   1984-08-02
#
#                 genres belongs_to_collection original_language  budget_musd  \
# id
# 2          Drama|Crime                   NaN                fi          NaN
# 2          Drama|Crime                   NaN                fi          NaN
# 3         Drama|Comedy                   NaN                fi          NaN
# 3         Drama|Comedy                   NaN                fi          NaN
# 5         Crime|Comedy                   NaN                en      4.00000
# ...                ...                   ...               ...          ...
# 468343   Drama|Romance                   NaN                fi          NaN
# 468707  Romance|Comedy                   NaN                fi      1.25404
# 468707  Romance|Comedy                   NaN                fi      1.25404
# 469172   Fantasy|Drama                   NaN                pt          NaN
# 469172   Fantasy|Drama                   NaN                pt          NaN
#
#         revenue_musd                               production_companies  ...  \
# id                                                                       ...
# 2                NaN  Villealfa Filmproduction Oy|Finnish Film Found...  ...
# 2                NaN  Villealfa Filmproduction Oy|Finnish Film Found...  ...
# 3                NaN                        Villealfa Filmproduction Oy  ...
# 3                NaN                        Villealfa Filmproduction Oy  ...
# 5                4.3                         Miramax Films|A Band Apart  ...
# ...              ...                                                ...  ...
# 468343           NaN                                                NaN  ...
# 468707           NaN                               Elokuvayhtiö Oy Aamu  ...
# 468707           NaN                               Elokuvayhtiö Oy Aamu  ...
# 469172           NaN  Institut National de l'Audiovisuel (INA)|Radio...  ...
# 469172           NaN  Institut National de l'Audiovisuel (INA)|Radio...  ...
#
#              spoken_languages  \
# id
# 2               suomi|Deutsch
# 2               suomi|Deutsch
# 3       English|suomi|svenska
# 3       English|suomi|svenska
# 5                     English
# ...                       ...
# 468343                    NaN
# 468707                  suomi
# 468707                  suomi
# 469172     Português|Français
# 469172     Português|Français
#
#                                               poster_path  \
# id
# 2       <img src='http://image.tmdb.org/t/p/w185//ojDg...
# 2       <img src='http://image.tmdb.org/t/p/w185//ojDg...
# 3       <img src='http://image.tmdb.org/t/p/w185//nj01...
# 3       <img src='http://image.tmdb.org/t/p/w185//nj01...
# 5       <img src='http://image.tmdb.org/t/p/w185//xhU6...
# ...                                                   ...
# 468343  <img src='http://image.tmdb.org/t/p/w185//q9mc...
# 468707  <img src='http://image.tmdb.org/t/p/w185//9M8x...
# 468707  <img src='http://image.tmdb.org/t/p/w185//9M8x...
# 469172  <img src='http://image.tmdb.org/t/p/w185//mipl...
# 469172  <img src='http://image.tmdb.org/t/p/w185//mipl...
#
#                                                      cast  cast_size  \
# id
# 2       Turo Pajala|Susanna Haavisto|Matti Pellonpää|E...          4
# 2       Turo Pajala|Susanna Haavisto|Matti Pellonpää|E...          4
# 3       Matti Pellonpää|Kati Outinen|Sakari Kuosmanen|...          7
# 3       Matti Pellonpää|Kati Outinen|Sakari Kuosmanen|...          7
# 5       Tim Roth|Antonio Banderas|Jennifer Beals|Madon...         24
# ...                                                   ...        ...
# 468343                                                NaN          0
# 468707  Inka Haapamäki|Rosa Honkonen|Tiitus Rantala|Sa...          6
# 468707  Inka Haapamäki|Rosa Honkonen|Tiitus Rantala|Sa...          6
# 469172  Ruben de Freitas|Teresa Madruga|Fernando Heito...         20
# 469172  Ruben de Freitas|Teresa Madruga|Fernando Heito...         20
#
#         crew_size          director profit_musd    ROI release_ts  \
# id
# 2               6    Aki Kaurismäki         NaN    NaN 1988-10-21
# 2               6    Aki Kaurismäki         NaN    NaN 1988-10-21
# 3              11    Aki Kaurismäki         NaN    NaN 1986-10-16
# 3              11    Aki Kaurismäki         NaN    NaN 1986-10-16
# 5              88    Allison Anders         0.3  1.075 1995-12-09
# ...           ...               ...         ...    ...        ...
# 468343          1      Jack Witikka         NaN    NaN 1956-01-01
# 468707          2  Hannaleena Hauru         NaN    NaN 2017-07-28
# 468707          2  Hannaleena Hauru         NaN    NaN 2017-07-28
# 469172         27         Raúl Ruiz         NaN    NaN 1984-08-02
# 469172         27         Raúl Ruiz         NaN    NaN 1984-08-02
#
#         has_franchise
# id
# 2               False
# 2               False
# 3               False
# 3               False
# 5               False
# ...               ...
# 468343          False
# 468707          False
# 468707          False
# 469172          False
# 469172          False
#
# [90225 rows x 26 columns]

# %%
genre_df.columns.to_list()
# Out:
# ['genre_name',
#  'title',
#  'tagline',
#  'release_date',
#  'genres',
#  'belongs_to_collection',
#  'original_language',
#  'budget_musd',
#  'revenue_musd',
#  'production_companies',
#  'production_countries',
#  'vote_count',
#  'vote_average',
#  'popularity',
#  'runtime',
#  'overview',
#  'spoken_languages',
#  'poster_path',
#  'cast',
#  'cast_size',
#  'crew_size',
#  'director',
#  'profit_musd',
#  'ROI',
#  'release_ts',
#  'has_franchise']

# %%
genre_wise_performence = genre_df.groupby('genre_name').agg({'budget_musd':['mean','sum','count'],'profit_musd':['mean','sum'],'revenue_musd':['mean','sum'],'ROI':['mean']})

# %%
genre_wise_performence.nlargest(20,('budget_musd','mean'))
# Out:
#                 budget_musd               profit_musd                 \
#                        mean           sum        mean            sum
# genre_name
# Adventure         51.093255  65705.926364  141.137342  135068.436282
# Fantasy           46.991335  34256.683311  137.242650   69856.509099
# Animation         46.738843  19957.486079  160.542398   46878.380145
# Family            46.620167  33519.899995  137.569937   72912.066603
# Action            36.766719  77688.077617   89.277186  126237.940703
# Science Fiction   35.450581  35344.229130   99.956942   63372.701088
# War               24.393692   7805.981356   45.462982    9228.985278
# Thriller          23.370518  55504.980272   51.565089   77399.199214
# History           23.274574   8914.161694   31.881720    7492.204166
# Western           22.542124   3178.439427   24.937032    2219.395832
# Mystery           22.434132  14425.146930   45.831507   20303.357592
# Crime             21.958441  27601.759972   41.942148   36112.189363
# Comedy            21.601565  60095.553370   55.292873  102291.814344
# Romance           17.484859  26034.954973   45.498836   46090.320974
# Drama             16.878877  70013.580668   35.622201   91940.901552
# Music             14.788680   4466.181321   46.692652    8964.989208
# Horror             9.336621  11820.161791   34.483605   20207.392515
# TV Movie           4.722342    179.449000   37.000000      37.000000
# Foreign            3.427392    401.004833    0.562131      18.550333
# Documentary        1.894464    464.143783   13.479185     781.792724
#
#                 revenue_musd                          ROI
#                         mean            sum          mean
# genre_name
# Adventure         179.192356  199978.669360   1071.170962
# Fantasy           166.006633  103920.152145      5.958486
# Animation         176.989426   67432.971320      6.765834
# Family            159.103683  107076.778493   1927.315280
# Action            116.073804  201388.050019    726.056558
# Science Fiction   131.516076   97847.960421      5.281461
# War                65.475137   15910.458263  20682.075826
# Thriller           69.520125  129724.552970    672.383836
# History            50.515927   14902.198420  17874.906652
# Western            43.782042    5122.498884      4.206550
# Mystery            63.190209   34754.614989     42.379596
# Crime              58.518680   63375.730411  14402.467253
# Comedy             64.097213  166845.045970   8373.127236
# Romance            51.272289   73473.190426  13275.649591
# Drama              43.826162  160754.363574  10134.654732
# Music              50.076001   13370.292367      5.970629
# Horror             41.955231   30837.094673   1746.946979
# TV Movie           42.000000      42.000000      8.400000
# Foreign             3.512486     291.536311      3.158545
# Documentary         6.647303    1449.112153    107.820303

# %%
genre_wise_performence.nlargest(20,('profit_musd','mean'))
# Out:
#                 budget_musd               profit_musd                 \
#                        mean           sum        mean            sum
# genre_name
# Animation         46.738843  19957.486079  160.542398   46878.380145
# Adventure         51.093255  65705.926364  141.137342  135068.436282
# Family            46.620167  33519.899995  137.569937   72912.066603
# Fantasy           46.991335  34256.683311  137.242650   69856.509099
# Science Fiction   35.450581  35344.229130   99.956942   63372.701088
# Action            36.766719  77688.077617   89.277186  126237.940703
# Comedy            21.601565  60095.553370   55.292873  102291.814344
# Thriller          23.370518  55504.980272   51.565089   77399.199214
# Music             14.788680   4466.181321   46.692652    8964.989208
# Mystery           22.434132  14425.146930   45.831507   20303.357592
# Romance           17.484859  26034.954973   45.498836   46090.320974
# War               24.393692   7805.981356   45.462982    9228.985278
# Crime             21.958441  27601.759972   41.942148   36112.189363
# TV Movie           4.722342    179.449000   37.000000      37.000000
# Drama             16.878877  70013.580668   35.622201   91940.901552
# Horror             9.336621  11820.161791   34.483605   20207.392515
# History           23.274574   8914.161694   31.881720    7492.204166
# Western           22.542124   3178.439427   24.937032    2219.395832
# Documentary        1.894464    464.143783   13.479185     781.792724
# Foreign            3.427392    401.004833    0.562131      18.550333
#
#                 revenue_musd                          ROI
#                         mean            sum          mean
# genre_name
# Animation         176.989426   67432.971320      6.765834
# Adventure         179.192356  199978.669360   1071.170962
# Family            159.103683  107076.778493   1927.315280
# Fantasy           166.006633  103920.152145      5.958486
# Science Fiction   131.516076   97847.960421      5.281461
# Action            116.073804  201388.050019    726.056558
# Comedy             64.097213  166845.045970   8373.127236
# Thriller           69.520125  129724.552970    672.383836
# Music              50.076001   13370.292367      5.970629
# Mystery            63.190209   34754.614989     42.379596
# Romance            51.272289   73473.190426  13275.649591
# War                65.475137   15910.458263  20682.075826
# Crime              58.518680   63375.730411  14402.467253
# TV Movie           42.000000      42.000000      8.400000
# Drama              43.826162  160754.363574  10134.654732
# Horror             41.955231   30837.094673   1746.946979
# History            50.515927   14902.198420  17874.906652
# Western            43.782042    5122.498884      4.206550
# Documentary         6.647303    1449.112153    107.820303
# Foreign             3.512486     291.536311      3.158545

# %%
genre_wise_performence.nlargest(20,('revenue_musd','mean'))
# Out:
#                 budget_musd               profit_musd                 \
#                        mean           sum        mean            sum
# genre_name
# Adventure         51.093255  65705.926364  141.137342  135068.436282
# Animation         46.738843  19957.486079  160.542398   46878.380145
# Fantasy           46.991335  34256.683311  137.242650   69856.509099
# Family            46.620167  33519.899995  137.569937   72912.066603
# Science Fiction   35.450581  35344.229130   99.956942   63372.701088
# Action            36.766719  77688.077617   89.277186  126237.940703
# Thriller          23.370518  55504.980272   51.565089   77399.199214
# War               24.393692   7805.981356   45.462982    9228.985278
# Comedy            21.601565  60095.553370   55.292873  102291.814344
# Mystery           22.434132  14425.146930   45.831507   20303.357592
# Crime             21.958441  27601.759972   41.942148   36112.189363
# Romance           17.484859  26034.954973   45.498836   46090.320974
# History           23.274574   8914.161694   31.881720    7492.204166
# Music             14.788680   4466.181321   46.692652    8964.989208
# Drama             16.878877  70013.580668   35.622201   91940.901552
# Western           22.542124   3178.439427   24.937032    2219.395832
# TV Movie           4.722342    179.449000   37.000000      37.000000
# Horror             9.336621  11820.161791   34.483605   20207.392515
# Documentary        1.894464    464.143783   13.479185     781.792724
# Foreign            3.427392    401.004833    0.562131      18.550333
#
#                 revenue_musd                          ROI
#                         mean            sum          mean
# genre_name
# Adventure         179.192356  199978.669360   1071.170962
# Animation         176.989426   67432.971320      6.765834
# Fantasy           166.006633  103920.152145      5.958486
# Family            159.103683  107076.778493   1927.315280
# Science Fiction   131.516076   97847.960421      5.281461
# Action            116.073804  201388.050019    726.056558
# Thriller           69.520125  129724.552970    672.383836
# War                65.475137   15910.458263  20682.075826
# Comedy             64.097213  166845.045970   8373.127236
# Mystery            63.190209   34754.614989     42.379596
# Crime              58.518680   63375.730411  14402.467253
# Romance            51.272289   73473.190426  13275.649591
# History            50.515927   14902.198420  17874.906652
# Music              50.076001   13370.292367      5.970629
# Drama              43.826162  160754.363574  10134.654732
# Western            43.782042    5122.498884      4.206550
# TV Movie           42.000000      42.000000      8.400000
# Horror             41.955231   30837.094673   1746.946979
# Documentary         6.647303    1449.112153    107.820303
# Foreign             3.512486     291.536311      3.158545

# %%
genre_wise_performence.nlargest(20,('ROI','mean'))
# Out:
#                 budget_musd               profit_musd                 \
#                        mean           sum        mean            sum
# genre_name
# War               24.393692   7805.981356   45.462982    9228.985278
# History           23.274574   8914.161694   31.881720    7492.204166
# Crime             21.958441  27601.759972   41.942148   36112.189363
# Romance           17.484859  26034.954973   45.498836   46090.320974
# Drama             16.878877  70013.580668   35.622201   91940.901552
# Comedy            21.601565  60095.553370   55.292873  102291.814344
# Family            46.620167  33519.899995  137.569937   72912.066603
# Horror             9.336621  11820.161791   34.483605   20207.392515
# Adventure         51.093255  65705.926364  141.137342  135068.436282
# Action            36.766719  77688.077617   89.277186  126237.940703
# Thriller          23.370518  55504.980272   51.565089   77399.199214
# Documentary        1.894464    464.143783   13.479185     781.792724
# Mystery           22.434132  14425.146930   45.831507   20303.357592
# TV Movie           4.722342    179.449000   37.000000      37.000000
# Animation         46.738843  19957.486079  160.542398   46878.380145
# Music             14.788680   4466.181321   46.692652    8964.989208
# Fantasy           46.991335  34256.683311  137.242650   69856.509099
# Science Fiction   35.450581  35344.229130   99.956942   63372.701088
# Western           22.542124   3178.439427   24.937032    2219.395832
# Foreign            3.427392    401.004833    0.562131      18.550333
#
#                 revenue_musd                          ROI
#                         mean            sum          mean
# genre_name
# War                65.475137   15910.458263  20682.075826
# History            50.515927   14902.198420  17874.906652
# Crime              58.518680   63375.730411  14402.467253
# Romance            51.272289   73473.190426  13275.649591
# Drama              43.826162  160754.363574  10134.654732
# Comedy             64.097213  166845.045970   8373.127236
# Family            159.103683  107076.778493   1927.315280
# Horror             41.955231   30837.094673   1746.946979
# Adventure         179.192356  199978.669360   1071.170962
# Action            116.073804  201388.050019    726.056558
# Thriller           69.520125  129724.552970    672.383836
# Documentary         6.647303    1449.112153    107.820303
# Mystery            63.190209   34754.614989     42.379596
# TV Movie           42.000000      42.000000      8.400000
# Animation         176.989426   67432.971320      6.765834
# Music              50.076001   13370.292367      5.970629
# Fantasy           166.006633  103920.152145      5.958486
# Science Fiction   131.516076   97847.960421      5.281461
# Western            43.782042    5122.498884      4.206550
# Foreign             3.512486     291.536311      3.158545

# %%
genre_wise_performence.nlargest(20,('budget_musd','count'))
# Out:
#                 budget_musd                     profit_musd                 \
#                        mean           sum count        mean            sum
# genre_name
# Drama             16.878877  70013.580668  4148   35.622201   91940.901552
# Comedy            21.601565  60095.553370  2782   55.292873  102291.814344
# Thriller          23.370518  55504.980272  2375   51.565089   77399.199214
# Action            36.766719  77688.077617  2113   89.277186  126237.940703
# Romance           17.484859  26034.954973  1489   45.498836   46090.320974
# Adventure         51.093255  65705.926364  1286  141.137342  135068.436282
# Horror             9.336621  11820.161791  1266   34.483605   20207.392515
# Crime             21.958441  27601.759972  1257   41.942148   36112.189363
# Science Fiction   35.450581  35344.229130   997   99.956942   63372.701088
# Fantasy           46.991335  34256.683311   729  137.242650   69856.509099
# Family            46.620167  33519.899995   719  137.569937   72912.066603
# Mystery           22.434132  14425.146930   643   45.831507   20303.357592
# Animation         46.738843  19957.486079   427  160.542398   46878.380145
# History           23.274574   8914.161694   383   31.881720    7492.204166
# War               24.393692   7805.981356   320   45.462982    9228.985278
# Music             14.788680   4466.181321   302   46.692652    8964.989208
# Documentary        1.894464    464.143783   245   13.479185     781.792724
# Western           22.542124   3178.439427   141   24.937032    2219.395832
# Foreign            3.427392    401.004833   117    0.562131      18.550333
# TV Movie           4.722342    179.449000    38   37.000000      37.000000
#
#                 revenue_musd                          ROI
#                         mean            sum          mean
# genre_name
# Drama              43.826162  160754.363574  10134.654732
# Comedy             64.097213  166845.045970   8373.127236
# Thriller           69.520125  129724.552970    672.383836
# Action            116.073804  201388.050019    726.056558
# Romance            51.272289   73473.190426  13275.649591
# Adventure         179.192356  199978.669360   1071.170962
# Horror             41.955231   30837.094673   1746.946979
# Crime              58.518680   63375.730411  14402.467253
# Science Fiction   131.516076   97847.960421      5.281461
# Fantasy           166.006633  103920.152145      5.958486
# Family            159.103683  107076.778493   1927.315280
# Mystery            63.190209   34754.614989     42.379596
# Animation         176.989426   67432.971320      6.765834
# History            50.515927   14902.198420  17874.906652
# War                65.475137   15910.458263  20682.075826
# Music              50.076001   13370.292367      5.970629
# Documentary         6.647303    1449.112153    107.820303
# Western            43.782042    5122.498884      4.206550
# Foreign             3.512486     291.536311      3.158545
# TV Movie           42.000000      42.000000      8.400000
